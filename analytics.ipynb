# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/csv/atracacao_fato.csv', sep = ';')
df
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 df = pd.read_csv('data/csv/atracacao_fato.csv', sep = ';')
#       2 df
#
# File ~/Documents/projects/fiec-test-project/venv/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df = pd.read_csv('data/txt/2021Atracacao.txt', sep = ';')
df
# Out:
#        IDAtracacao    CDTUP      IDBerco                  Berço  \
# 0          1200419    BRSTM      STM0502                SAN0502
# 1          1206357    BRSTM      STM0502                SAN0502
# 2             3298       BR          NaN                    NaN
# 3          1187610    BRSTM      STM0502                SAN0502
# 4          1158910    BRBEL      BEL0001                     01
# ...            ...      ...          ...                    ...
# 77742      1215450  BRAM069  BRAM0695001  Berço 1 - Rampa móvel
# 77743      1215458  BRAM069  BRAM0695001  Berço 1 - Rampa móvel
# 77744      1215477  BRPA043  BRPA0435001         Píer de Navios
# 77745      1215493  BRPA043  BRPA0435001         Píer de Navios
# 77746      1215539  BRPA043  BRPA0435001         Píer de Navios
#
#               Porto Atracação       Apelido Instalação Portuária  \
# 0                    Santarém                                NaN
# ...

# %%
df[['Data Atracação','Data Chegada']]
# Out:
#             Data Atracação         Data Chegada
# 0      15/11/2021 08:02:00  15/11/2021 08:00:00
# 1      01/12/2021 14:07:00  01/12/2021 14:05:00
# 2                      NaN                  NaN
# 3      03/09/2021 17:52:00  03/09/2021 17:50:00
# 4      26/05/2021 20:15:00  26/05/2021 20:15:00
# ...                    ...                  ...
# 77742  20/12/2021 08:00:00  20/12/2021 07:00:00
# 77743  29/12/2021 08:00:00  29/12/2021 07:00:00
# 77744  22/12/2021 10:36:00  17/12/2021 10:36:00
# 77745  25/12/2021 12:54:00  22/12/2021 01:24:00
# 77746  09/12/2021 12:25:00  06/12/2021 07:50:00
#
# [77747 rows x 2 columns]

# %%
df[['Data Início Operação','Data Atracação']]
# Out:
#       Data Início Operação       Data Atracação
# 0      15/11/2021 08:10:00  15/11/2021 08:02:00
# 1      01/12/2021 14:10:00  01/12/2021 14:07:00
# 2                      NaN                  NaN
# 3      03/09/2021 17:55:00  03/09/2021 17:52:00
# 4      26/05/2021 20:30:00  26/05/2021 20:15:00
# ...                    ...                  ...
# 77742  20/12/2021 09:00:00  20/12/2021 08:00:00
# 77743  29/12/2021 09:00:00  29/12/2021 08:00:00
# 77744  22/12/2021 16:05:00  22/12/2021 10:36:00
# 77745  25/12/2021 19:07:00  25/12/2021 12:54:00
# 77746  09/12/2021 22:32:00  09/12/2021 12:25:00
#
# [77747 rows x 2 columns]

# %%
type(df['Data Desatracação'])
# Out:
# pandas.core.series.Series

# %%
dff = spark.createDataFrame([('1997-02-28 10:30:00',)], ['t'])
dff.select(to_timestamp(df.t, 'yyyy-MM-dd HH:mm:ss').alias('dt')).collect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 dff = spark.createDataFrame([('1997-02-28 10:30:00',)], ['t'])
#       2 dff.select(to_timestamp(df.t, 'yyyy-MM-dd HH:mm:ss').alias('dt')).collect()
#
# NameError: name 'spark' is not defined

# %%
df.columns
# Out:
# Index(['IDAtracacao', 'CDTUP', 'IDBerco', 'Berço', 'Porto Atracação',
#        'Apelido Instalação Portuária', 'Complexo Portuário',
#        'Tipo da Autoridade Portuária', 'Data Atracação', 'Data Chegada',
#        'Data Desatracação', 'Data Início Operação', 'Data Término Operação',
#        'Ano', 'Mes', 'Tipo de Operação', 'Tipo de Navegação da Atracação',
#        'Nacionalidade do Armador', 'FlagMCOperacaoAtracacao', 'Terminal',
#        'Município', 'UF', 'SGUF', 'Região Geográfica', 'Nº da Capitania',
#        'Nº do IMO'],
#       dtype='object')

# %%
df['Mes']
# Out:
# 0        nov
# 1        dez
# 2        ago
# 3        set
# 4        mai
#         ...
# 77742    dez
# 77743    dez
# 77744    dez
# 77745    dez
# 77746    dez
# Name: Mes, Length: 77747, dtype: object

# %%
df = pd.read_csv('data/txt/2021Carga.txt', sep = ';')
df
# Out:
# /tmp/ipykernel_9954/3487334646.py:1: DtypeWarning: Columns (12,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/txt/2021Carga.txt', sep = ';')
#           IDCarga  IDAtracacao Origem Destino CDMercadoria  \
# 0        27502716      1126626  BR200   BRBEL         2710
# 1        27502733      1126639  BRBEL   BRMCP         2710
# 2        27502734      1126639  BRBEL   BRMCP         2207
# 3        27502737      1126643  USHOU   BRBEL         2710
# 4        27502738      1126643  USHOU   BRBEL         2710
# ...           ...          ...    ...     ...          ...
# 2350075      3333         3333  BRISA   BR289         2505
# 2350076      3334         3334  BRISA   BR289         2505
# 2350077      3335         3335  BR368   BR372         2505
# 2350078      3336         3336  BR368   BR372         2505
# 2350079      3337         3337  BR365   BR369         1212
#
# ...

# %%
df.columns
# Out:
# Index(['IDCarga', 'IDAtracacao', 'Origem', 'Destino', 'CDMercadoria',
#        'Tipo Operação da Carga', 'Carga Geral Acondicionamento',
#        'ConteinerEstado', 'Tipo Navegação', 'FlagAutorizacao', 'FlagCabotagem',
#        'FlagCabotagemMovimentacao', 'FlagConteinerTamanho', 'FlagLongoCurso',
#        'FlagMCOperacaoCarga', 'FlagOffshore', 'FlagTransporteViaInterioir',
#        'Percurso Transporte em vias Interiores',
#        'Percurso Transporte Interiores', 'STNaturezaCarga', 'STSH2', 'STSH4',
#        'Natureza da Carga', 'Sentido', 'TEU', 'QTCarga', 'VLPesoCargaBruta'],
#       dtype='object')

# %%
df = pd.read_csv('data/2021Carga_Conteinerizada.txt', sep = ';')
df
# Out:
# /tmp/ipykernel_9954/2328187549.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/2021Carga_Conteinerizada.txt', sep = ';')
#           IDCarga CDMercadoriaConteinerizada VLPesoCargaConteinerizada
# 0        27673235                       0101                      4,22
# 1        27697257                       0101                      4,99
# 2        27697277                       0101                      5,71
# 3        27697280                       0101                      1,84
# 4        27748701                       0101                      23,3
# ...           ...                        ...                       ...
# 4211517  30197852                       R9P0                         0
# 4211518  30545592                       R9P0                         0
# 4211519  30607145                       R9P0                         0
# ...

# %%
df = pd.read_csv('data/2021Carga_Regiao.txt', sep = ';')
df
# Out:
#          IDCarga            Região Hidrográfica ValorMovimentado
# 0       27502716                            NaN         2476,460
# 1       27502737                            NaN         4551,950
# 2       27502738                            NaN          834,730
# 3       27502739                            NaN          417,370
# 4       27502740                            NaN         3937,240
# ...          ...                            ...              ...
# 536722      3333  Região Hidrográfica do Paraná         2400,000
# 536723      3334  Região Hidrográfica do Paraná         2400,000
# 536724      3335  Região Hidrográfica do Paraná        11750,000
# 536725      3336  Região Hidrográfica do Paraná         9500,000
# 536726      3337  Região Hidrográfica do Paraná            26322
#
# [536727 rows x 3 columns]

# %%
df = pd.read_csv('data/2021TemposAtracacao.txt', sep = ';')
df
# Out:
#        IDAtracacao   TEsperaAtracacao   TEsperaInicioOp        TOperacao  \
# 0          1169791     15,29999999993   5,4166666666861  88,583333333256
# 1          1169990    104,86666666676   6,2999999999302  20,100000000035
# 2          1169992   0,48333333333721  0,18333333340706  26,749999999884
# 3          1170005   0,48333333333721  0,18333333323244  64,250000000058
# 4          1170006   0,48333333333721  0,18333333323244  1,1666666668025
# ...            ...                ...               ...              ...
# 75046      1205640  0,016666666720994                 0                0
# 75047      1205639  0,016666666720994                 0                0
# 75048      1205651  0,016666666720994                 0                0
# 75049      1205650  0,016666666720994                 0                0
# 75050      1205645  0,016666666720994                 0                0
#
#       TEsperaDesatracacao        TAtracado         TEstadia
# ...
